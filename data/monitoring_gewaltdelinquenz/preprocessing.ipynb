# %%
import pandas as pd

# %%
# Dtype string to avoid dropping leading zeros in PLR_ID
df_overall = pd.read_csv('raw/gesamt.csv', dtype=str)
df_fam_part = pd.read_csv('raw/innerfam_partner.csv', dtype=str)
df_youth = pd.read_csv('raw/jugend.csv', dtype=str)

# %%
# Well merge based on the plr_id later
df_plr = df_overall.loc[:, ['plr_name', 'plr_id']].copy()
# Rename
df_plr = df_plr.rename(columns={'plr_name': 'PLR_NAME', 'plr_id': 'PLR_ID'})

# %%
# columns are the same for all three dataframes
df_overall.columns
# Out:
# Index(['gisid', 'kategorie', 'bez_name', 'bez_id', 'pgr_name', 'pgr_id',
#        'bzr_name', 'bzr_id', 'plr_name', 'plr_id'],
#       dtype='object')

# %%
# Split the category entry into two columns: 1 - Niedrig --> 1, Niedrig
# Only keep relevant rows
def preprocess_inplace(df, prefix):
    entries = df['kategorie'].str.split(' - ', expand=True)
    df[prefix + 'n'] = entries[0]
    df[prefix + 'v'] = entries[1]
    drop_list = [
        'gisid', 'kategorie', 'bez_name', 'bez_id', 'pgr_name', 'pgr_id',
        'bzr_name', 'bzr_id', 'plr_name']
    df.drop(drop_list, axis=1, inplace=True)
    df.rename(columns={'plr_id': 'PLR_ID'}, inplace=True)

preprocess_inplace(df_overall, 'overall_')
preprocess_inplace(df_fam_part, 'innerfam_partner_')
preprocess_inplace(df_youth, 'youth_')

# %%
df = df_plr \
    .merge(df_overall, on='PLR_ID', how='outer') \
    .merge(df_fam_part, on='PLR_ID', how='outer') \
    .merge(df_youth, on='PLR_ID', how='outer')

# %%
df
# Out:
#                     PLR_NAME    PLR_ID overall_n     overall_v
# 0               Stülerstraße  01100101         2        Mittel  \
# 1          Großer Tiergarten  01100102         4  Stark erhöht
# 2               Lützowstraße  01100103         3        Erhöht
# 3               Körnerstraße  01100104         2        Mittel
# 4              Wilhelmstraße  01100205         3        Erhöht
# ..                       ...       ...       ...           ...
# 537        Rollbergesiedlung  12601032         2        Mittel
# 538  Treuenbrietzener Straße  12601133         2        Mittel
# 539       Märkisches Zentrum  12601134         2        Mittel
# 540         Dannenwalder Weg  12601235         2        Mittel
# 541        Schorfheidestraße  12601236         2        Mittel
#
#     innerfam_partner_n innerfam_partner_v youth_n       youth_v
# 0                    2             Mittel       1       Niedrig
# 1                    3             Erhöht       4  Stark erhöht
# 2                    3             Erhöht       2        Mittel
# 3                    2             Mittel       2        Mittel
# 4                    2             Mittel       3        Erhöht
# ..                 ...                ...     ...           ...
# 537                  3             Erhöht       2        Mittel
# 538                  4       Stark erhöht       2        Mittel
# 539                  3             Erhöht       3        Erhöht
# 540                  3             Erhöht       2        Mittel
# 541                  2             Mittel       2        Mittel
#
# [542 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['PLR_NAME', 'PLR_ID', 'overall_n', 'overall_v', 'innerfam_partner_n',
#        'innerfam_partner_v', 'youth_n', 'youth_v'],
#       dtype='object')

# %%
# Export easy version
easy_columns = [
    'PLR_NAME', 'PLR_ID', 'overall_v', 'innerfam_partner_v', 'youth_v']
df_easy = df[easy_columns].copy()

rename_dict = {
    'overall_v': 'Violent Delinquency Overall',
    'innerfam_partner_v': 'Domestic and Partner Violence',
    'youth_v': 'Youth Violence'
}
df_easy.rename(columns=rename_dict, inplace=True)

# %%
df_easy
# Out:
#                     PLR_NAME    PLR_ID Violent Delinquency Overall
# 0               Stülerstraße  01100101                      Mittel  \
# 1          Großer Tiergarten  01100102                Stark erhöht
# 2               Lützowstraße  01100103                      Erhöht
# 3               Körnerstraße  01100104                      Mittel
# 4              Wilhelmstraße  01100205                      Erhöht
# ..                       ...       ...                         ...
# 537        Rollbergesiedlung  12601032                      Mittel
# 538  Treuenbrietzener Straße  12601133                      Mittel
# 539       Märkisches Zentrum  12601134                      Mittel
# 540         Dannenwalder Weg  12601235                      Mittel
# 541        Schorfheidestraße  12601236                      Mittel
#
#     Domestic and Partner Violence Youth Violence
# 0                          Mittel        Niedrig
# 1                          Erhöht   Stark erhöht
# 2                          Erhöht         Mittel
# 3                          Mittel         Mittel
# 4                          Mittel         Erhöht
# ..                            ...            ...
# 537                        Erhöht         Mittel
# 538                  Stark erhöht         Mittel
# 539                        Erhöht         Erhöht
# 540                        Erhöht         Mittel
# 541                        Mittel         Mittel
#
# [542 rows x 5 columns]

# %%
df.to_csv('violent_delinquency.csv', index=False)
df_easy.to_csv('violent_delinquency_easy.csv', index=False)
